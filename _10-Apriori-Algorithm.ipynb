# %% [markdown]
# # ASSOCIATION RULE LEARNING

# %% [markdown]
# # <H2> APRIORI ALGORITHM </H2>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Shaik.AbdulRazak\OneDrive\Documents\Raw data\groceries-groceries.csv")
data.head()
# Out:
#              Item 1         Item 2          Item 3                    Item 4  \
# 0      citrus fruit  semi-finished       margarine               ready soups
# 1    tropical fruit            NaN             NaN                    coffee
# 2        whole milk            NaN             NaN                       NaN
# 3         pip fruit         yogurt    cream cheese              meat spreads
# 4  other vegetables     whole milk  condensed milk  long life bakery product
#
#   Item 5 Item 6 Item 7 Item 8 Item 9 Item 10 Item 11
# 0    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 1    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 2    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 3    NaN    NaN    NaN    NaN    NaN     NaN     NaN
# 4    NaN    NaN    NaN    NaN    NaN     NaN     NaN

# %%
data.shape
# Out:
# (300, 11)

# %%
for i in range(0,data.shape[0]):
    for j in data.columns:
        print(data[j][i])
# Out:
# citrus fruit
# semi-finished
# margarine
# ready soups
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# nan
# nan
# coffee
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# pip fruit
# yogurt
# cream cheese
# meat spreads
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# whole milk
# condensed milk
# long life bakery product
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# butter
# yogurt
# rice
# abrasive cleaner
# nan
# nan
# nan
# nan
# nan
# nan
# rolls/buns
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# UHT-milk
# rolls/buns
# bottled beer
# liquor (appetizer)
# nan
# nan
# nan
# nan
# nan
# nan
# potted plants
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# cereals
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# other vegetables
# white bread
# bottled water
# chocolate
# nan
# nan
# nan
# nan
# nan
# nan
# citrus fruit
# tropical fruit
# whole milk
# butter
# curd
# yogurt
# flour
# bottled water
# dishes
# nan
# nan
# sugar
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# frankfurter
# rolls/buns
# soda
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# chicken
# tropical fruit
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# butter
# sugar
# fruit/vegetables
# newspapers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# fruit/vegetable juice
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# packaged fruit/vegetables
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# chocolate
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# specialty bar
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# butter
# milk
# pastry
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# cream cheese
# processed cheese
# detergent
# newspapers
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# root vegetables
# other vegetables
# frozen dessert
# rolls/buns
# flour
# sweet spreads
# salty snack
# waffles
# candy
# bathroom cleaner
# bottled water
# canned beer
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# yogurt
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# citrus fruit
# semi-finished
# margarine
# ready soups
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# nan
# nan
# coffee
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# pip fruit
# yogurt
# cream cheese
# meat spreads
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# whole milk
# condensed milk
# long life bakery product
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# butter
# yogurt
# rice
# abrasive cleaner
# nan
# nan
# nan
# nan
# nan
# nan
# rolls/buns
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# UHT-milk
# rolls/buns
# bottled beer
# liquor (appetizer)
# nan
# nan
# nan
# nan
# nan
# nan
# potted plants
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# cereals
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# other vegetables
# white bread
# bottled water
# chocolate
# nan
# nan
# nan
# nan
# nan
# nan
# citrus fruit
# tropical fruit
# whole milk
# butter
# curd
# yogurt
# flour
# bottled water
# dishes
# nan
# nan
# sugar
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# frankfurter
# rolls/buns
# soda
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# chicken
# tropical fruit
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# butter
# sugar
# fruit/vegetables
# newspapers
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# fruit/vegetable juice
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# packaged fruit/vegetables
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# chocolate
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# specialty bar
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# butter
# milk
# pastry
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# cream cheese
# processed cheese
# detergent
# newspapers
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# root vegetables
# other vegetables
# frozen dessert
# rolls/buns
# flour
# sweet spreads
# salty snack
# waffles
# candy
# bathroom cleaner
# bottled water
# canned beer
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# yogurt
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# citrus fruit
# semi-finished
# margarine
# ready soups
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# tropical fruit
# nan
# nan
# coffee
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# pip fruit
# yogurt
# cream cheese
# meat spreads
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# other vegetables
# whole milk
# condensed milk
# long life bakery product
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# whole milk
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
market=[]
for i in range(0,data.shape[0]):
    cus=[]
    for j in data.columns:
        if type(data[j][i])==str:
            cus.append(data[j][i])
    market.append(cus)

# %%
l=[]
for i in market:
    for j in i:
        l.append(j)

# %%
l
# Out:
# ['citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk',
#  'pip fruit',
#  'yogurt',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'whole milk',
#  'condensed milk',
#  'long life bakery product',
#  'whole milk',
#  'butter',
#  'yogurt',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'other vegetables',
#  'UHT-milk',
#  'rolls/buns',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  'whole milk',
#  'cereals',
#  'tropical fruit',
#  'other vegetables',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  'citrus fruit',
#  'tropical fruit',
#  'whole milk',
#  'butter',
#  'curd',
#  'yogurt',
#  'flour',
#  'bottled water',
#  'dishes',
#  'sugar',
#  'frankfurter',
#  'rolls/buns',
#  'soda',
#  'chicken',
#  'tropical fruit',
#  'butter',
#  'sugar',
#  'fruit/vegetables',
#  'newspapers',
#  'fruit/vegetable juice',
#  'packaged fruit/vegetables',
#  'chocolate',
#  'specialty bar',
#  'other vegetables',
#  'butter',
#  'milk',
#  'pastry',
#  'whole milk',
#  'tropical fruit',
#  'cream cheese',
#  'processed cheese',
#  'detergent',
#  'newspapers',
#  'tropical fruit',
#  'root vegetables',
#  'other vegetables',
#  'frozen dessert',
#  'rolls/buns',
#  'flour',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'bottled water',
#  'canned beer',
#  'yogurt',
#  'citrus fruit',
#  'semi-finished',
#  'margarine',
#  'ready soups',
#  'tropical fruit',
#  'coffee',
#  'whole milk']

# %%
market
# Out:
# [['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk'],
#  ['pip fruit', 'yogurt', 'cream cheese', 'meat spreads'],
#  ['other vegetables',
#   'whole milk',
#   'condensed milk',
#   'long life bakery product'],
#  ['whole milk', 'butter', 'yogurt', 'rice', 'abrasive cleaner'],
#  ['rolls/buns'],
#  ['other vegetables',
#   'UHT-milk',
#   'rolls/buns',
#   'bottled beer',
#   'liquor (appetizer)'],
#  ['potted plants'],
#  ['whole milk', 'cereals'],
#  ['tropical fruit',
#   'other vegetables',
#   'white bread',
#   'bottled water',
#   'chocolate'],
#  ['citrus fruit',
#   'tropical fruit',
#   'whole milk',
#   'butter',
#   'curd',
#   'yogurt',
#   'flour',
#   'bottled water',
#   'dishes'],
#  ['sugar'],
#  ['frankfurter', 'rolls/buns', 'soda'],
#  ['chicken', 'tropical fruit'],
#  ['butter', 'sugar', 'fruit/vegetables', 'newspapers'],
#  ['fruit/vegetable juice'],
#  ['packaged fruit/vegetables'],
#  ['chocolate'],
#  ['specialty bar'],
#  ['other vegetables'],
#  ['butter', 'milk', 'pastry'],
#  ['whole milk'],
#  ['tropical fruit',
#   'cream cheese',
#   'processed cheese',
#   'detergent',
#   'newspapers'],
#  ['tropical fruit',
#   'root vegetables',
#   'other vegetables',
#   'frozen dessert',
#   'rolls/buns',
#   'flour',
#   'sweet spreads',
#   'salty snack',
#   'waffles',
#   'candy',
#   'bathroom cleaner'],
#  ['bottled water', 'canned beer'],
#  ['yogurt'],
#  ['citrus fruit', 'semi-finished', 'margarine', 'ready soups'],
#  ['tropical fruit', 'coffee'],
#  ['whole milk']]

# %%
import collections
collections.Counter(l)
# Out:
# Counter({'tropical fruit': 67,
#          'whole milk': 67,
#          'other vegetables': 55,
#          'yogurt': 44,
#          'butter': 44,
#          'rolls/buns': 44,
#          'bottled water': 33,
#          'citrus fruit': 23,
#          'cream cheese': 22,
#          'chocolate': 22,
#          'flour': 22,
#          'sugar': 22,
#          'newspapers': 22,
#          'semi-finished': 12,
#          'margarine': 12,
#          'ready soups': 12,
#          'coffee': 12,
#          'pip fruit': 11,
#          'meat spreads': 11,
#          'condensed milk': 11,
#          'long life bakery product': 11,
#          'rice': 11,
#          'abrasive cleaner': 11,
#          'UHT-milk': 11,
#          'bottled beer': 11,
#          'liquor (appetizer)': 11,
#          'potted plants': 11,
#          'cereals': 11,
#          'white bread': 11,
#          'curd': 11,
#          'dishes': 11,
#          'frankfurter': 11,
#          'soda': 11,
#          'chicken': 11,
#          'fruit/vegetables': 11,
#          'fruit/vegetable juice': 11,
#          'packaged fruit/vegetables': 11,
#          'specialty bar': 11,
#          'milk': 11,
#          'pastry': 11,
#          'processed cheese': 11,
#          'detergent': 11,
#          'root vegetables': 11,
#          'frozen dessert': 11,
#          'sweet spreads': 11,
#          'salty snack': 11,
#          'waffles': 11,
#          'candy': 11,
#          'bathroom cleaner': 11,
#          'canned beer': 11})

# %%
p=collections.Counter(l)

# %%
p.keys()
# Out:
# dict_keys(['citrus fruit', 'semi-finished', 'margarine', 'ready soups', 'tropical fruit', 'coffee', 'whole milk', 'pip fruit', 'yogurt', 'cream cheese', 'meat spreads', 'other vegetables', 'condensed milk', 'long life bakery product', 'butter', 'rice', 'abrasive cleaner', 'rolls/buns', 'UHT-milk', 'bottled beer', 'liquor (appetizer)', 'potted plants', 'cereals', 'white bread', 'bottled water', 'chocolate', 'curd', 'flour', 'dishes', 'sugar', 'frankfurter', 'soda', 'chicken', 'fruit/vegetables', 'newspapers', 'fruit/vegetable juice', 'packaged fruit/vegetables', 'specialty bar', 'milk', 'pastry', 'processed cheese', 'detergent', 'root vegetables', 'frozen dessert', 'sweet spreads', 'salty snack', 'waffles', 'candy', 'bathroom cleaner', 'canned beer'])

# %%
p.values()
# Out:
# dict_values([23, 12, 12, 12, 67, 12, 67, 11, 44, 22, 11, 55, 11, 11, 44, 11, 11, 44, 11, 11, 11, 11, 11, 11, 33, 22, 11, 22, 11, 22, 11, 11, 11, 11, 22, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11, 11])

# %%
d={"ItemName":p.keys(),"values":p.values()}
pd.DataFrame(d)
# Out:
#                      ItemName  values
# 0                citrus fruit      23
# 1               semi-finished      12
# 2                   margarine      12
# 3                 ready soups      12
# 4              tropical fruit      67
# 5                      coffee      12
# 6                  whole milk      67
# 7                   pip fruit      11
# 8                      yogurt      44
# 9                cream cheese      22
# 10               meat spreads      11
# 11           other vegetables      55
# 12             condensed milk      11
# 13   long life bakery product      11
# 14                     butter      44
# 15                       rice      11
# 16           abrasive cleaner      11
# 17                 rolls/buns      44
# 18                   UHT-milk      11
# 19               bottled beer      11
# 20         liquor (appetizer)      11
# 21              potted plants      11
# 22                    cereals      11
# 23                white bread      11
# 24              bottled water      33
# 25                  chocolate      22
# 26                       curd      11
# 27                      flour      22
# 28                     dishes      11
# 29                      sugar      22
# 30                frankfurter      11
# 31                       soda      11
# 32                    chicken      11
# 33           fruit/vegetables      11
# 34                 newspapers      22
# 35      fruit/vegetable juice      11
# 36  packaged fruit/vegetables      11
# 37              specialty bar      11
# 38                       milk      11
# 39                     pastry      11
# 40           processed cheese      11
# 41                  detergent      11
# 42            root vegetables      11
# 43             frozen dessert      11
# 44              sweet spreads      11
# 45                salty snack      11
# 46                    waffles      11
# 47                      candy      11
# 48           bathroom cleaner      11
# 49                canned beer      11

# %%
pd.DataFrame(d).sort_values(by=["values"],ascending=False)
# Out:
#                      ItemName  values
# 6                  whole milk      67
# 4              tropical fruit      67
# 11           other vegetables      55
# 17                 rolls/buns      44
# 14                     butter      44
# 8                      yogurt      44
# 24              bottled water      33
# 0                citrus fruit      23
# 25                  chocolate      22
# 9                cream cheese      22
# 27                      flour      22
# 29                      sugar      22
# 34                 newspapers      22
# 1               semi-finished      12
# 3                 ready soups      12
# 2                   margarine      12
# 5                      coffee      12
# 7                   pip fruit      11
# 16           abrasive cleaner      11
# 15                       rice      11
# 12             condensed milk      11
# 13   long life bakery product      11
# 10               meat spreads      11
# 21              potted plants      11
# 18                   UHT-milk      11
# 20         liquor (appetizer)      11
# 22                    cereals      11
# 23                white bread      11
# 26                       curd      11
# 28                     dishes      11
# 30                frankfurter      11
# 31                       soda      11
# 32                    chicken      11
# 19               bottled beer      11
# 33           fruit/vegetables      11
# 35      fruit/vegetable juice      11
# 36  packaged fruit/vegetables      11
# 37              specialty bar      11
# 38                       milk      11
# 39                     pastry      11
# 40           processed cheese      11
# 41                  detergent      11
# 42            root vegetables      11
# 43             frozen dessert      11
# 44              sweet spreads      11
# 45                salty snack      11
# 46                    waffles      11
# 47                      candy      11
# 48           bathroom cleaner      11
# 49                canned beer      11

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr=TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
tr.transform(market)
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]], shape=(300, 50))

# %%
df=pd.DataFrame(tr.transform(market),columns=tr.columns_)
df
# Out:
#      UHT-milk  abrasive cleaner  bathroom cleaner  bottled beer  \
# 0       False             False             False         False
# 1       False             False             False         False
# 2       False             False             False         False
# 3       False             False             False         False
# 4       False             False             False         False
# ..        ...               ...               ...           ...
# 295     False             False             False         False
# 296     False             False             False         False
# 297     False             False             False         False
# 298     False             False             False         False
# 299     False             False             False         False
#
#      bottled water  butter  candy  canned beer  cereals  chicken  ...  \
# 0            False   False  False        False    False    False  ...
# 1            False   False  False        False    False    False  ...
# 2            False   False  False        False    False    False  ...
# 3            False   False  False        False    False    False  ...
# 4            False   False  False        False    False    False  ...
# ..             ...     ...    ...          ...      ...      ...  ...
# 295           True   False  False         True    False    False  ...
# 296          False   False  False        False    False    False  ...
# 297          False   False  False        False    False    False  ...
# 298          False   False  False        False    False    False  ...
# 299          False   False  False        False    False    False  ...
#
#      semi-finished   soda  specialty bar  sugar  sweet spreads  \
# 0             True  False          False  False          False
# 1            False  False          False  False          False
# 2            False  False          False  False          False
# 3            False  False          False  False          False
# 4            False  False          False  False          False
# ..             ...    ...            ...    ...            ...
# 295          False  False          False  False          False
# 296          False  False          False  False          False
# 297           True  False          False  False          False
# 298          False  False          False  False          False
# 299          False  False          False  False          False
#
#      tropical fruit  waffles  white bread  whole milk  yogurt
# 0             False    False        False       False   False
# 1              True    False        False       False   False
# 2             False    False        False        True   False
# 3             False    False        False       False    True
# 4             False    False        False        True   False
# ..              ...      ...          ...         ...     ...
# 295           False    False        False       False   False
# 296           False    False        False       False    True
# 297           False    False        False       False   False
# 298            True    False        False       False   False
# 299           False    False        False        True   False
#
# [300 rows x 50 columns]

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(df,min_support=0.07,use_colnames=True,max_len=3).sort_values(by=["support"])
# Out:
#      support                            itemsets
# 2   0.073333                         (chocolate)
# 6   0.073333                        (newspapers)
# 5   0.073333                             (flour)
# 4   0.073333                      (cream cheese)
# 13  0.073333     (tropical fruit, bottled water)
# 14  0.073333                (whole milk, butter)
# 15  0.073333                    (butter, yogurt)
# 9   0.073333                             (sugar)
# 19  0.073333                (whole milk, yogurt)
# 18  0.073333  (other vegetables, tropical fruit)
# 17  0.073333      (rolls/buns, other vegetables)
# 20  0.073333        (whole milk, butter, yogurt)
# 16  0.073333             (tropical fruit, flour)
# 3   0.076667                      (citrus fruit)
# 0   0.110000                     (bottled water)
# 8   0.146667                        (rolls/buns)
# 1   0.146667                            (butter)
# 12  0.146667                            (yogurt)
# 7   0.183333                  (other vegetables)
# 11  0.223333                        (whole milk)
# 10  0.223333                    (tropical fruit)
