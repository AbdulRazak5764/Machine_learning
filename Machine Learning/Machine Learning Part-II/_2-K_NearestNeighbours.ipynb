# %% [markdown]
# # K-Nearest Neighbours (K-NN)

# %% [markdown]
# # K-NN (Classification)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Shaik.AbdulRazak\OneDrive\Documents\Raw data\Social_Network_Ads_100.csv")
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   59            60619          1
# 1   37            72124          1
# 2   55            80149          0
# 3   42            41616          0
# 4   31            76799          0

# %%
data.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
x=data.iloc[:,:-1]
y=data["Purchased"]

# %%
sns.scatterplot(x="Age",y="EstimatedSalary",data=data,hue="Purchased")
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(x)
sc.transform(x)
# Out:
# array([[ 1.75586018, -0.52276212],
#        [-0.19509558, -0.22520137],
#        [ 1.40114095, -0.01764596],
#        [ 0.24830346, -1.01424815],
#        [-0.72717442, -0.10428903],
#        [-0.99321384,  0.63080628],
#        [ 0.86906211,  1.26855099],
#        [-0.99321384, -1.04365507],
#        [-0.37245519,  0.86213034],
#        [ 0.42566307, -0.25781537],
#        [-0.37245519,  0.432898  ],
#        [ 0.07094385, -1.27973803],
#        [-0.99321384, -0.54329782],
#        [-0.10641577, -1.40910777],
#        [-1.52529268, -0.55806593],
#        [ 0.07094385, -0.71399759],
#        [ 1.66718038, -1.38055436],
#        [ 0.24830346,  0.30681293],
#        [ 1.66718038, -1.29567001],
#        [-1.08189365, -0.46394828],
#        [-0.01773596,  1.5821989 ],
#        [-0.28377538, -0.53706469],
#        [-1.88001191,  1.77459824],
#        [-1.34793307, -1.42610016],
#        [-1.61397249, -0.52477948],
#        [-1.88001191,  0.02978789],
#        [-0.63849461,  1.42031861],
# ...

# %%
x=pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=11) # we change the neighbor value because to get the perfect accuracy
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
knn.score(x_test,y_test)*100
# Out:
# 55.00000000000001

# %%
knn.score(x_train,y_train)*100
# Out:
# 58.75

# %%
for i in range(1,30):
    knn1=KNeighborsClassifier()
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 67.5 45.0
# 2 67.5 45.0
# 3 67.5 45.0
# 4 67.5 45.0
# 5 67.5 45.0
# 6 67.5 45.0
# 7 67.5 45.0
# 8 67.5 45.0
# 9 67.5 45.0
# 10 67.5 45.0
# 11 67.5 45.0
# 12 67.5 45.0
# 13 67.5 45.0
# 14 67.5 45.0
# 15 67.5 45.0
# 16 67.5 45.0
# 17 67.5 45.0
# 18 67.5 45.0
# 19 67.5 45.0
# 20 67.5 45.0
# 21 67.5 45.0
# 22 67.5 45.0
# 23 67.5 45.0
# 24 67.5 45.0
# 25 67.5 45.0
# 26 67.5 45.0
# 27 67.5 45.0
# 28 67.5 45.0
# 29 67.5 45.0

# %%
knn.predict([[59 , 60619]])
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([1])

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn1)
plt.show()
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # K-NN (Regression)

# %%
data1=pd.read_csv(r"C:\Users\Shaik.AbdulRazak\OneDrive\Documents\Raw data\Multiple_Regression - 1.csv")
data1.head()
# Out:
#     Age   Salary  Experience2
# 0  24.0  62914.0          0.1
# 1  51.0  93456.0          1.8
# 2  47.0  81181.0          1.6
# 3  38.0  94493.0          2.9
# 4  38.0  83516.0          0.8

# %%
data1.isnull().sum()
# Out:
# Age            1048075
# Salary         1048075
# Experience2          0
# dtype: int64

# %%
data1["Age"].mode()[0]
data1["Age"].fillna(data["Age"].mode()[0],inplace=True)
# Out:
# C:\Users\Shaik.AbdulRazak\AppData\Local\Temp\ipykernel_18484\838994338.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1["Age"].fillna(data["Age"].mode()[0],inplace=True)

# %%
data1["Salary"].mode()[0]
data1["Salary"].fillna(data["Age"].mode()[0],inplace=True)
# Out:
# C:\Users\Shaik.AbdulRazak\AppData\Local\Temp\ipykernel_18484\2849804631.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1["Salary"].fillna(data["Age"].mode()[0],inplace=True)

# %%
data1.isnull().sum()
# Out:
# Age            0
# Salary         0
# Experience2    0
# dtype: int64

# %%
x=data1.drop(columns="Salary")
x
# Out:
#           Age  Experience2
# 0        24.0          0.1
# 1        51.0          1.8
# 2        47.0          1.6
# 3        38.0          2.9
# 4        38.0          0.8
# ...       ...          ...
# 1048570  37.0          0.0
# 1048571  37.0          0.0
# 1048572  37.0          0.0
# 1048573  37.0          0.0
# 1048574  37.0          0.0
#
# [1048575 rows x 2 columns]

# %%
y=data1["Salary"]
y
# Out:
# 0          62914.0
# 1          93456.0
# 2          81181.0
# 3          94493.0
# 4          83516.0
#             ...
# 1048570       37.0
# 1048571       37.0
# 1048572       37.0
# 1048573       37.0
# 1048574       37.0
# Name: Salary, Length: 1048575, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
# to create a model
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
knn.score(x_test,y_test)*100
# Out:
# 99.12068409257824

# %%
knn.score(x_train,y_train)*100
