# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# # Classification

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Shaik.AbdulRazak\OneDrive\Documents\Raw data\placement.csv")
data.head()
# Out:
#    cgpa  score  placed
# 0  6.87   5.26       0
# 1  9.75   7.66       1
# 2  8.66   7.70       1
# 3  7.99   8.19       1
# 4  5.78   8.63       0

# %%
data.isnull().sum()
# Out:
# cgpa      0
# score     0
# placed    0
# dtype: int64

# %%
sns.scatterplot(x="cgpa",y="score",data=data,hue="placed")
plt.show()

# %%
x=data.iloc[:,:-1]
y=data["placed"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.svm import SVC
sv=SVC(kernel='linear') # kernel is linear
sv.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sv.score(x_test,y_test)*100
# Out:
# 83.33333333333334

# %%
sv.score(x_train,y_train)*100
# Out:
# 85.0

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(), y.to_numpy(),clf=sv)
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.svm import SVC
sv1=SVC(kernel='poly') # kernel is poly
sv1.fit(x_train,y_train)
# Out:
# SVC(kernel='poly')

# %%
sv1.score(x_test,y_test)*100
# Out:
# 100.0

# %%
sv1.score(x_train,y_train)*100
# Out:
# 99.16666666666667

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(), y.to_numpy(),clf=sv1)
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.svm import SVC
sv2=SVC(kernel='rbf') # kernel is rbf
sv2.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv2.score(x_test,y_test)*100
# Out:
# 98.33333333333333

# %%
sv2.score(x_train,y_train)*100
# Out:
# 96.66666666666667

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(), y.to_numpy(),clf=sv2)
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
from sklearn.svm import SVC
sv3=SVC(kernel='sigmoid') # kernel is sigmoid
sv3.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
sv3.score(x_train,y_train)*100
# Out:
# 55.00000000000001

# %%
sv3.score(x_test,y_test)*100
# Out:
# 38.333333333333336

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x.to_numpy(), y.to_numpy(),clf=sv3)
# Out:
# c:\Users\Shaik.AbdulRazak\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
# from sklearn.svm import SVC
# sv3=SVC(kernel='precomputed') # kernel is precomputed ( it only used for if the data is only in 0 and 1)
# sv3.fit(x_train,y_train)

# %% [markdown]
# # SVM (Regression)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data1=pd.read_csv(r"C:\Users\Shaik.AbdulRazak\OneDrive\Documents\Raw data\placement_data.csv")
data1.head()
# Out:
#    Cgpa  Package
# 0  6.87    12.21
# 1  9.75    22.55
# 2  8.66    24.33
# 3  7.99    20.76
# 4  5.78    15.66

# %%
data1.isnull().sum()
# Out:
# Cgpa       0
# Package    0
# dtype: int64

# %%
x=data1[["Cgpa"]]
y=data1["Package"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR
sr=SVR(kernel="poly") # kernel=('sigmoid', 'linear', 'rbf', 'poly', 'precomputed')
sr.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sr.score(x_test,y_test)*100
# Out:
# 42.402386765405296

# %%
sr.score(x_train,y_train)*100
# Out:
# 51.33471809794612

# %%
sns.scatterplot(x="Cgpa",y="Package",data=data1)
plt.plot(data1["Cgpa"],sr.predict(x),color="red")
plt.show()

# %%
sns.scatterplot(x="Cgpa",y="Package",data=data1)
plt.scatter(data1["Cgpa"],sr.predict(x),color="red")
plt.show()
